# %% [markdown]
# <a href="https://colab.research.google.com/github/AMSecretAgent/ResearchProject/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Research workflow using GitHub + Colab + Mendeley")

import numpy as np
data = np.array([10,20,30,40,50])

print("Average value:", np.mean(data))
# Out:
# Research workflow using GitHub + Colab + Mendeley
# Average value: 30.0
